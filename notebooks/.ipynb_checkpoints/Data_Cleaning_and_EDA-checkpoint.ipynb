# %%
# %pip install causal-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 174 kB 12.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 47 kB 4.3 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 106 kB 30.4 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#Data Cleaning
import pandas as pd
gut_microbes = pd.read_csv("/content/gut_16s_abundance.txt", sep = "\t")
gut_microbes.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_171/2219880556.py in <module>
#       1 #Data Cleaning
#       2 import pandas as pd
# ----> 3 gut_microbes = pd.read_csv("/content/gut_16s_abundance.txt", sep = "\t")
#       4 gut_microbes.head()
#
# ...

# %%
subject_info = pd.read_csv("/content/subject_file.csv")
subject_info.head()
# Out:
#   SubjectID          Study Race Sex    Age    BMI   SSPG IR_IS_classification
# 0   ZIS22OE            HMP    C   F    NaN    NaN    NaN              Unknown
# 1   ZJBOZ2X       Exercise    C   F  65.30  19.82    NaN              Unknown
# 2   ZJOSZHK            HMP    C   M  41.43  19.42    NaN              Unknown
# 3   ZJTKAE3            HMP    C   F  58.65  31.24  162.0                   IR
# 4   ZJXC41N  HMP, Exercise    B   F  49.69  28.24   75.0                   IS

# %%
gut_microbes['SubjectID'] = gut_microbes['SampleID'].str.split('-').str[0]

# %%
len(set(gut_microbes['SubjectID']))
# Out:
# 96

# %%
len(set(subject_info['SubjectID']))
# Out:
# 107

# %%
len(set(gut_microbes['SubjectID']).intersection(set(subject_info['SubjectID'])))
# Out:
# 96

# %%
merged_df = pd.merge(gut_microbes, subject_info, on='SubjectID', how='left')

# %%
merged_df.head()
# Out:
#        SampleID  phylum_Actinobacteria  phylum_Bacteroidetes  \
# 0  ZOZOW1T-1010               0.000449              0.650866
# 1  ZOZOW1T-1011               0.000176              0.730518
# 2  ZOZOW1T-1012               0.000597              0.178364
# 3  ZOZOW1T-1015               0.000058              0.740726
# 4  ZOZOW1T-1021               0.001113              0.554580
#
#    phylum_Firmicutes  phylum_Proteobacteria  phylum_Verrucomicrobia  \
# 0           0.225080               0.007364                0.015835
# 1           0.184808               0.003900                0.008186
# 2           0.796861               0.000358                0.002788
# 3           0.226516               0.005977                0.001207
# 4           0.364195               0.038358                0.000059
#
#    phylum_unclassified_Bacteria  class_Actinobacteria  class_Bacilli  \
# 0                      0.097431              0.000449       0.000138
# ...

# %%
subset_subjects = list(set(merged_df['SubjectID']))[:20]

subset_df = merged_df[merged_df['SubjectID'].isin(subset_subjects)]

#print(len(subset_df))
subset_df.head()
# Out:
# 161
#        SampleID  phylum_Actinobacteria  phylum_Bacteroidetes  \
# 130  ZO94RDZ-02               0.011876              0.623849
# 131  ZO94RDZ-04               0.021855              0.638403
# 132  ZO94RDZ-05               0.043622              0.607992
# 133  ZO94RDZ-06               0.000116              0.735687
# 134  ZO94RDZ-07               0.001113              0.737369
#
#      phylum_Firmicutes  phylum_Proteobacteria  phylum_Verrucomicrobia  \
# 130           0.311052               0.023897                0.004460
# 131           0.312440               0.012113                0.000128
# 132           0.294278               0.026905                0.002028
# 133           0.246313               0.010568                0.000000
# 134           0.250471               0.000343                0.000000
#
#      phylum_unclassified_Bacteria  class_Actinobacteria  class_Bacilli  \
# 130                      0.024867              0.011876       0.000097
# ...

# %%
#Start EDA + import package to play with algorithm
from causallearn.search.ConstraintBased.FCI import fci
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-35-8dd3df65d072> in <cell line: 2>()
#       1 #import package play with algorithm
# ----> 2 from causallearn.search.ConstraintBased.FCI import fci
#
# ModuleNotFoundError: No module named 'causallearn'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
