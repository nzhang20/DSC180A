# %%
pip install causal-learn
# Out:
# Collecting causal-learnNote: you may need to restart the kernel to use updated packages.
#
#   Using cached causal_learn-0.1.3.8-py3-none-any.whl (174 kB)
# Requirement already satisfied: statsmodels in c:\users\zhang\anaconda\lib\site-packages (from causal-learn) (0.13.2)
# Requirement already satisfied: scipy in c:\users\zhang\anaconda\lib\site-packages (from causal-learn) (1.9.1)
# Requirement already satisfied: numpy in c:\users\zhang\anaconda\lib\site-packages (from causal-learn) (1.24.4)
# Requirement already satisfied: tqdm in c:\users\zhang\anaconda\lib\site-packages (from causal-learn) (4.64.1)
# Requirement already satisfied: networkx in c:\users\zhang\anaconda\lib\site-packages (from causal-learn) (2.8.4)
# Requirement already satisfied: pydot in c:\users\zhang\anaconda\lib\site-packages (from causal-learn) (3.0.2)
# Collecting graphviz
#   Using cached graphviz-0.20.3-py3-none-any.whl (47 kB)
# Requirement already satisfied: scikit-learn in c:\users\zhang\anaconda\lib\site-packages (from causal-learn) (1.0.2)
# Requirement already satisfied: pandas in c:\users\zhang\anaconda\lib\site-packages (from causal-learn) (1.4.4)
# Requirement already satisfied: matplotlib in c:\users\zhang\anaconda\lib\site-packages (from causal-learn) (3.5.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\zhang\anaconda\lib\site-packages (from matplotlib->causal-learn) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\zhang\anaconda\lib\site-packages (from matplotlib->causal-learn) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\zhang\anaconda\lib\site-packages (from matplotlib->causal-learn) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\zhang\anaconda\lib\site-packages (from matplotlib->causal-learn) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\zhang\anaconda\lib\site-packages (from matplotlib->causal-learn) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\zhang\anaconda\lib\site-packages (from matplotlib->causal-learn) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\zhang\anaconda\lib\site-packages (from matplotlib->causal-learn) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\zhang\anaconda\lib\site-packages (from pandas->causal-learn) (2022.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\zhang\anaconda\lib\site-packages (from scikit-learn->causal-learn) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\zhang\anaconda\lib\site-packages (from scikit-learn->causal-learn) (1.1.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\zhang\anaconda\lib\site-packages (from statsmodels->causal-learn) (0.5.2)
# Requirement already satisfied: colorama in c:\users\zhang\anaconda\lib\site-packages (from tqdm->causal-learn) (0.4.5)
# Requirement already satisfied: six in c:\users\zhang\anaconda\lib\site-packages (from patsy>=0.5.2->statsmodels->causal-learn) (1.16.0)
# Installing collected packages: graphviz, causal-learn
# Successfully installed causal-learn-0.1.3.8 graphviz-0.20.3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from causallearn.search.ConstraintBased.PC import pc
from causallearn.utils.GraphUtils import GraphUtils
from causallearn.utils.PCUtils.BackgroundKnowledge import BackgroundKnowledge
from causallearn.graph.GraphNode import GraphNode
import pydot
from IPython.display import Image, display

# %%
# gut microbes
gut_microbes = pd.read_csv("../datasets/gut_16s_abundance.txt", sep = "\t")
gut_microbes.head()
# Out:
#        SampleID  phylum_Actinobacteria  phylum_Bacteroidetes  \
# 0  ZOZOW1T-1010               0.000449              0.650866
# 1  ZOZOW1T-1011               0.000176              0.730518
# 2  ZOZOW1T-1012               0.000597              0.178364
# 3  ZOZOW1T-1015               0.000058              0.740726
# 4  ZOZOW1T-1021               0.001113              0.554580
#
#    phylum_Firmicutes  phylum_Proteobacteria  phylum_Verrucomicrobia  \
# 0           0.225080               0.007364                0.015835
# 1           0.184808               0.003900                0.008186
# 2           0.796861               0.000358                0.002788
# 3           0.226516               0.005977                0.001207
# 4           0.364195               0.038358                0.000059
#
#    phylum_unclassified_Bacteria  class_Actinobacteria  class_Bacilli  \
# 0                      0.097431              0.000449       0.000138
# 1                      0.070902              0.000176       0.000070
# 2                      0.020911              0.000597       0.000119
# 3                      0.024971              0.000058       0.000029
# 4                      0.041286              0.001113       0.000059
#
#    class_Bacteroidia  ...  genus_Veillonella  genus_unclassified_Bacteria  \
# 0           0.650866  ...           0.000000                     0.097431
# 1           0.730518  ...           0.000035                     0.070902
# 2           0.178364  ...           0.000080                     0.020911
# 3           0.740726  ...           0.000029                     0.024971
# 4           0.554580  ...           0.000410                     0.041286
#
#    genus_unclassified_Clostridiales  \
# 0                          0.007883
# 1                          0.008713
# 2                          0.022903
# 3                          0.013046
# 4                          0.006208
#
#    genus_unclassified_Clostridiales_Incertae.Sedis.XIII  \
# 0                                           0.000035
# 1                                           0.000141
# 2                                           0.000518
# 3                                           0.000086
# 4                                           0.000117
#
#    genus_unclassified_Coriobacteriaceae  \
# 0                              0.000415
# 1                              0.000176
# 2                              0.000398
# 3                              0.000029
# 4                              0.000176
#
#    genus_unclassified_Erysipelotrichaceae  genus_unclassified_Firmicutes  \
# 0                                0.002386                       0.015697
# 1                                0.000808                       0.008608
# 2                                0.001713                       0.000876
# 3                                0.004109                       0.007730
# 4                                0.000468                       0.000996
#
#    genus_unclassified_Lachnospiraceae  genus_unclassified_Porphyromonadaceae  \
# 0                            0.027452                               0.000000
# 1                            0.011805                               0.000000
# 2                            0.018362                               0.000000
# 3                            0.043849                               0.000029
# 4                            0.132584                               0.015753
#
#    genus_unclassified_Ruminococcaceae
# 0                            0.074128
# 1                            0.069215
# 2                            0.615351
# 3                            0.067096
# 4                            0.044624
#
# [5 rows x 97 columns]

# %%
# gut_microbes.isnull().sum().sum() -> this is 0
gut_microbes_numeric = gut_microbes.drop(columns=['SampleID'])

# %%
# drop columns with very low variance
gut_microbes_numeric = gut_microbes_numeric.loc[:, gut_microbes_numeric.var() > 1e-5]
gut_microbes_numeric.head()
# Out:
#    phylum_Actinobacteria  phylum_Bacteroidetes  phylum_Firmicutes  \
# 0               0.000449              0.650866           0.225080
# 1               0.000176              0.730518           0.184808
# 2               0.000597              0.178364           0.796861
# 3               0.000058              0.740726           0.226516
# 4               0.001113              0.554580           0.364195
#
#    phylum_Proteobacteria  phylum_Verrucomicrobia  \
# 0               0.007364                0.015835
# 1               0.003900                0.008186
# 2               0.000358                0.002788
# 3               0.005977                0.001207
# 4               0.038358                0.000059
#
#    phylum_unclassified_Bacteria  class_Actinobacteria  class_Bacilli  \
# 0                      0.097431              0.000449       0.000138
# 1                      0.070902              0.000176       0.000070
# 2                      0.020911              0.000597       0.000119
# 3                      0.024971              0.000058       0.000029
# 4                      0.041286              0.001113       0.000059
#
#    class_Bacteroidia  class_Betaproteobacteria  ...  genus_Ruminococcus  \
# 0           0.650866                  0.001936  ...                 0.0
# 1           0.730518                  0.001511  ...                 0.0
# 2           0.178364                  0.000080  ...                 0.0
# 3           0.740726                  0.001178  ...                 0.0
# 4           0.554580                  0.011595  ...                 0.0
#
#    genus_Streptococcus  genus_Veillonella  genus_unclassified_Bacteria  \
# 0             0.000138           0.000000                     0.097431
# 1             0.000035           0.000035                     0.070902
# 2             0.000040           0.000080                     0.020911
# 3             0.000029           0.000029                     0.024971
# 4             0.000059           0.000410                     0.041286
#
#    genus_unclassified_Clostridiales  genus_unclassified_Erysipelotrichaceae  \
# 0                          0.007883                                0.002386
# 1                          0.008713                                0.000808
# 2                          0.022903                                0.001713
# 3                          0.013046                                0.004109
# 4                          0.006208                                0.000468
#
#    genus_unclassified_Firmicutes  genus_unclassified_Lachnospiraceae  \
# 0                       0.015697                            0.027452
# 1                       0.008608                            0.011805
# 2                       0.000876                            0.018362
# 3                       0.007730                            0.043849
# 4                       0.000996                            0.132584
#
#    genus_unclassified_Porphyromonadaceae  genus_unclassified_Ruminococcaceae
# 0                               0.000000                            0.074128
# 1                               0.000000                            0.069215
# 2                               0.000000                            0.615351
# 3                               0.000029                            0.067096
# 4                               0.015753                            0.044624
#
# [5 rows x 80 columns]

# %%
# removing highly correlated columns bc was giving error earlier 
# ValueError: Data correlation matrix is singular. Cannot run fisherz test. Please check your data.

corr_matrix = gut_microbes_numeric.corr().abs()

# upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

# find columns with correlation greater than a threshold (e.g., 0.95)
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]
gut_microbes_numeric = gut_microbes_numeric.drop(columns=to_drop)

# %% [raw]
# gut_microbes_numeric

# %%
# data input for FCI must be numpy array
data = np.array(gut_microbes_numeric)
#data
# Out:
# array([[4.49469000e-04, 6.50866093e-01, 2.25080386e-01, ...,
#         2.74522010e-02, 0.00000000e+00, 7.41278570e-02],
#        [1.75673000e-04, 7.30517883e-01, 1.84807814e-01, ...,
#         1.18052140e-02, 0.00000000e+00, 6.92150940e-02],
#        [5.97467000e-04, 1.78363738e-01, 7.96861308e-01, ...,
#         1.83621450e-02, 0.00000000e+00, 6.15350912e-01],
#        ...,
#        [9.66183600e-03, 5.32155797e-01, 4.45727657e-01, ...,
#         3.05706520e-02, 1.82669080e-02, 3.58544690e-02],
#        [2.60721800e-03, 7.76423717e-01, 2.04212562e-01, ...,
#         9.78439200e-03, 1.72838100e-03, 2.16486990e-02],
#        [3.74855510e-02, 3.52837563e-01, 5.84466340e-01, ...,
#         7.37601140e-02, 1.21318875e-01, 3.25865580e-02]])

# %%
from causallearn.search.ConstraintBased.FCI import fci
from causallearn.utils.cit import fisherz  # import the independence test method 

independent_test_method = fisherz

# default parameters
g, edges = fci(data)

# or customized parameters
g, edges = fci(data, independence_test_method, alpha, depth, max_path_length,
    verbose, background_knowledge, cache_variables_map)

# visualization
from causallearn.utils.GraphUtils import GraphUtils

pdy = GraphUtils.to_pydot(g)
pdy.write_png('simple_test.png')
# Out:
#   0%|          | 0/47 [00:00<?, ?it/s]
# X3 --> X2
# X2 --> X15
# X6 --> X12
# X25 --> X6
# X13 --> X7
# X9 --> X30
# X9 --> X31
# X44 --> X9
# X23 --> X13
# X37 --> X21
# X37 --> X22
# X43 --> X24
# X25 --> X47
# X29 --> X34
# X34 --> X39
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_45404\1068643835.py in <module>
#       8
#       9 # or customized parameters
# ---> 10 g, edges = fci(data, independence_test_method, alpha, depth, max_path_length,
#      11     verbose, background_knowledge, cache_variables_map)
#      12
#
# NameError: name 'independence_test_method' is not defined

# %% [raw]
# pip show causal-learn

# %% [raw]
# from causallearn.search.ConstraintBased.PC import pc
